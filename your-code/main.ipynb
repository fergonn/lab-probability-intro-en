# %% [markdown]
# # Probability

# %% [markdown]
# ## Challenge 1
# There is a box with 10 white balls, 12 red balls and 8 black balls. Calculate the probability of:
# * Taking a white ball out.
# * Taking a white ball on first extraction and a black ball out on second extraction without replacing the first one.
# * Taking a white ball on first extraction and a black ball out on second extraction replacing the first one.
# * Taking 3 balls and them being all different colours.

# %%
white = 10
red = 12
black = 8
total = white + red + black

# %%
white_prob = (white / total)*100
print(f"The probability of taking a white ball out is {white_prob:.2f}%")
# Out:
# The probability of taking a white ball out is 33.33%

# %%
p_white = white / total
p_black = black /(total-1)
p_white_then_black = p_white * p_black

print(f"The probability of taking a white ball on the first extraction and a black ball on the second without replacing is {p_white_then_black:.2f}%")
# Out:
# The probability of taking a white ball on the first extraction and a black ball on the second without replacing is 0.09%

# %%
p_black_2 = black / total
p_white_black = p_white * p_black_2

print(f"The probability of taking a white ball on the first extraction and a black ball on the second replacing the first one is {p_white_black:.2f}%")
# Out:
# The probability of taking a white ball on the first extraction and a black ball on the second replacing the first one is 0.09%

# %%
fav_comb = 10 * 12 * 8
pos_comb = (30 * 29 * 28) / (3 * 2)

three_ball_prob = (fav_comb / pos_comb)*100

print(f"The probability of taking 3 balls and all being different colors is {three_ball_prob:.2f}%")
# Out:
# The probability of taking 3 balls and all being different colors is 23.65%

# %% [markdown]
# ## Challenge 2
#
# You want to go on picnic on Saturday. You hate rain, and would know to plan your weekend. To help you make a decision, you gather the following data about rainy days:
#
# * 40% of all days are cloudy.
# * About 50% of cloudy days are rainy.
# * About 20% of non-cloudy days are rainy.
#
# What is the chance of rain during next Saturday?

# %%
# Cloudy days
p_c = 0.4

# Cloudy days that are rainy
p_c_r = 0.5

# Rain on non cludy days
p_r_nc = 0.2

# None cludy days
nc = 1 - p_c

# %%
p_rain = (p_c_r * p_c) + (p_r_nc * nc)
pct_rain = p_rain * 100

print(f"The chance of rain during next Saturday is {pct_rain:.2f}%")
# Out:
# The chance of rain during next Saturday is 32.00%

# %% [markdown]
# ## Challenge 3
#
# A and B are events of a probability such that $P(A) = 0.3$, $P(B) = 0.6$ and $P(A \cap B) = 0.1$
#
# Which of the following statements are true?
# **HINT: draw a big Venn Diagram by your side**
# * $P(\overline{A}) = 0.7$
# * $P(A \cup B) = 0.6$
# * $P(A \cap \overline{B}) = 0.2$
# * $P(A \cup \overline{A}) = 1$
# * $P(A \cap (B \cup \overline{B})) = 0.4$
# * $P(\overline{A} \cap \overline{B}) = 0.3$
# * $P(\overline{A \cap B}) = 0.9$

# %%
# Given probabilities
P_A = 0.3
P_B = 0.6
P_A_and_B = 0.1

# Helper function to round consistently
def r(x):
    return round(x, 2)

results = {
    "P(~A) = 0.7": r(1 - P_A) == 0.7,

    "P(A ∪ B) = 0.6": r(P_A + P_B - P_A_and_B) == 0.6,

    "P(A ∩ ~B) = 0.2": r(P_A - P_A_and_B) == 0.2,

    "P(A ∪ ~A) = 1": r(1) == 1.0,

    "P(A ∩ (B ∪ ~B)) = 0.4": r(P_A) == 0.4,

    "P(~A ∩ ~B) = 0.3": r(1 - (P_A + P_B - P_A_and_B)) == 0.3,

    "P(~(A ∩ B)) = 0.9": r(1 - P_A_and_B) == 0.9
}

# Display results
for i, is_true in results.items():
    print(f"{i} → {is_true}")
# Out:
# P(~A) = 0.7 → True
# P(A ∪ B) = 0.6 → False
# P(A ∩ ~B) = 0.2 → True
# P(A ∪ ~A) = 1 → True
# P(A ∩ (B ∪ ~B)) = 0.4 → False
# P(~A ∩ ~B) = 0.3 → False
# P(~(A ∩ B)) = 0.9 → True

# %% [markdown]
# ## Challenge 4
#
#  * If someone flies to China, the probability of getting Covid is 1%
#  * If someone flies to Italy, the probability of getting Covid is 20%
#
# I roll 1 dice with numbers 1, 2, 3, 4, 5, 6:
#  * If 1: I fly to Italy
#  * If not 1: I fly to China
#
# During my trip, I got Covid. What is the probability that I flew to China?

# %%
# Given probabilities
P_china = 5 / 6
P_italy = 1 / 6

P_covid_given_china = 0.01
P_covid_given_italy = 0.20

# Total probability of getting Covid
P_covid = (P_covid_given_china * P_china + P_covid_given_italy * P_italy)

# Bayes' theorem
P_china_given_covid = (P_covid_given_china * P_china) / P_covid
P_china_given_covid = P_china_given_covid*100

# Print result rounded to 2 decimals
print(f"Probability of having flown to China given Covid: {round(P_china_given_covid, 2)}%")
# Out:
# Probability of having flown to China given Covid: 20.0%

# %% [markdown]
# ### Bonus

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Number of simulations
n_simulations = 10000

# Simulate dice rolls
die_1 = np.random.randint(1, 7, n_simulations)
die_2 = np.random.randint(1, 7, n_simulations)

# Sum of the dice
dice_sum = die_1 + die_2

# Create DataFrame
df_sim = pd.DataFrame({"sum": dice_sum})

# Show empirical probabilities for 7, 8, 9
empirical_probs = df_sim["sum"].value_counts(normalize=True).sort_index()

print("Empirical probabilities:")
print(empirical_probs.loc[[7, 8, 9]].round(3))
# Out:
# Empirical probabilities:
# sum
# 7    0.164
# 8    0.139
# 9    0.112
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(10, 6))

sns.histplot(
    df_sim["sum"],
    bins=range(2, 14),
    discrete=True
)

plt.xlabel("Result")
plt.ylabel("Count")
plt.title("Distribution of Dice Sums (10,000 Simulations)")

plt.show()
